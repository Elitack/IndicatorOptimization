# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import tensorflow as tf

# %matplotlib inline 
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
#有中文出现的情况，需要u'内容'

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="3"

import scipy.stats as stats
from datum import *
import model
import sys

# %%
vali_list = []
test_list = []
base_vali_list = []
base_test_list = []

# %%
def select(top_num, vali, test):
    vali_abs = np.abs(vali)
    arg_sort = np.argsort(vali_abs)
    select_arg = arg_sort[-top_num:]
    print('minimum: {}'.format(vali[select_arg[0]]))
    select_vali = vali[select_arg]
    select_test = test[select_arg]
    true_test = np.abs(select_test)
    #true_test = np.nan_to_num(select_test * select_vali / np.abs(select_vali))
    print('mean: {}'.format(true_test.mean()))
    return true_test, select_arg

# %%
# model_num_list = [54, 120, 77, 136, 115, 137, 60, 106, 195]
model_num_list = [74, 121, 169, 72, 84, 69, 90, 163, 140]

# %%
for i in range(3):
    data = Datum('{}_{}_{}'.format(2004010120140101+i, 2014010120150101, 'year'))
    data.data_prepare()
    data.get_embedding()
    data.supervised_data_prepare()
    data.ic_prepare()

    reload(model)
    tf.reset_default_graph()
    mod = model.Model(1, '{}_{}_{}'.format(2004010120140101+i, 2014010120150101, 'year'))
    mod.data_initial(data)
    mod.data_split()
    mod.factor_network() 
    
    for j in range(3):
        model_num = j
        saver = tf.train.Saver(max_to_keep=50)
        data_dir = '/data/zhige_data/embedding_simpyear/'
        with tf.Session() as sess:
            saver.restore(sess, data_dir+'{}model_{}/logmodel.ckpt'.format(model_num, mod.param))
            rank_ic = np.zeros((mod.vali_test-mod.train_vali, 44, 4))
            embedding = mod.data.embedding[:len(mod.data.list_stocks), :]
            for count_day, day in enumerate(range(mod.train_vali,mod.vali_test)):#batch_num
                for fac_idx in range(44):
                    feature = mod.data.feature_data[:, day, fac_idx]
                    if feature.std() != 0:
                        feature = (feature-feature.min()) / (feature.max() - feature.min())
                    else:
                        continue
                    label = mod.data.ar_ic[:, day, 2]
                    feed_dict = {mod.embedding: embedding, mod.factor: feature, mod.factor_index: [fac_idx], mod.ic: label}
                    new_f, loss_val = sess.run([mod.new_f, mod.cost], feed_dict=feed_dict)
                    for ic_idx in range(4):
                        rank_ic[count_day, fac_idx, ic_idx] = stats.spearmanr(mod.data.ar_ic[:, day, ic_idx], new_f)[0]
            vali_ic_mean = rank_ic.mean(axis=0)[:, 2]
            vali_list.append(vali_ic_mean)

            rank_ic = np.zeros((mod.day_sample-mod.vali_test, 44, 4))
            embedding = mod.data.embedding[:len(mod.data.list_stocks), :]
            print('test: model:{}'.format(model_num))
            for count_day, day in enumerate(range(mod.vali_test, mod.day_sample)):#batch_num
                for fac_idx in range(44):
                    feature = mod.data.feature_data[:, day, fac_idx]
                    if feature.std() != 0:
                        feature = (feature-feature.min()) / (feature.max() - feature.min())
                    else:
                        continue
                    label = mod.data.ar_ic[:, day, 2]
                    feed_dict = {mod.embedding: embedding, mod.factor: feature, mod.factor_index: [fac_idx], mod.ic: label}
                    new_f, loss_val = sess.run([mod.new_f, mod.cost], feed_dict=feed_dict)
                    for ic_idx in range(4):
                        rank_ic[count_day, fac_idx, ic_idx] = stats.spearmanr(mod.data.ar_ic[:, day, ic_idx], new_f)[0]
            avg_ic = rank_ic.mean(axis=0)[:, 2]
            test_list.append(avg_ic)
            print(np.abs(avg_ic))
            print(np.abs(avg_ic).mean())

# %%
rank_ic = np.zeros((mod.vali_test-mod.train_vali, 44, 4))
for count_day, day in enumerate(range(mod.train_vali,mod.vali_test)):#batch_num
    for fac_idx in range(44):
        feature = mod.data.feature_data[:, day, fac_idx]
        for ic_idx in range(4):
            rank_ic[count_day, fac_idx, ic_idx] = np.nan_to_num(stats.spearmanr(mod.data.ar_ic[:, day, ic_idx], feature)[0])
vali_ic_mean = rank_ic.mean(axis=0)[:, 2]
base_vali_list.append(vali_ic_mean)           

rank_ic = np.zeros((mod.day_sample-mod.vali_test, 44, 4))
for count_day, day in enumerate(range(mod.vali_test, mod.day_sample)):#batch_num
    for fac_idx in range(44):
        feature = mod.data.feature_data[:, day, fac_idx]
        for ic_idx in range(4):
            rank_ic[count_day, fac_idx, ic_idx] = np.nan_to_num(stats.spearmanr(mod.data.ar_ic[:, day, ic_idx], feature)[0])
avg_ic = rank_ic.mean(axis=0)[:, 2]
base_test_list.append(avg_ic)
print(np.abs(avg_ic))
print(np.abs(avg_ic).mean())

# %%
select_fac, select_arg = select(10, base_vali_list[-1], base_test_list[-1])
# Out:
# minimum: -0.0545751454819
# mean: 0.01659142034

# %%
select_fac, select_arg = select(10, base_vali_list[-1], base_test_list[-1])
# Out:
# minimum: -0.0545751454819
# mean: 0.01659142034

# %%
mean = 0
for i in range(9):
    select_fac, select_arg = select(10, vali_list[i], test_list[i])
    mean += select_fac.mean()
print(mean / 9)
# Out:
# minimum: -0.0339730178652
# mean: 0.0298754754885
# minimum: -0.0373978967926
# mean: 0.0405774194888
# minimum: -0.0371365634515
# mean: 0.0419635731394
# minimum: -0.0364474752867
# mean: 0.0413431474203
# minimum: -0.0425383954331
# mean: 0.0364402264974
# minimum: -0.0334798548638
# mean: 0.0522400247479
# minimum: -0.0339003164195
# mean: 0.0564219443569
# minimum: -0.0381342271703
# mean: 0.0351002750826
# minimum: -0.0376467119545
# mean: 0.0437687824046
# 0.041970096514

# %%
select_fac, select_arg = select(10, base_vali_list[-1], base_test_list[-1])
# Out:
# minimum: -0.0550318780993
# mean: 0.0247253521618

# %%
mean = 0
for i in range(9):
    select_fac, select_arg = select(10, vali_list[i], test_list[i])
    mean += select_fac.mean()
print(mean / 9)

# %%
pd.DataFrame(np.abs(np.array(test_list)).mean(axis=0)).to_csv(data_dir+'test_2014.csv')

# %%
pd.DataFrame(np.abs(np.array(base_test_list)).mean(axis=0)).to_csv(data_dir+'baseline_test_2014.csv')

# %% [markdown]
# # Visualize Weight

# %%
list_confidence = []
list_data = []
list_mod = []
for i in range(3):
    data = Datum('{}_{}_{}'.format(2004010120140101+i, 2014010120150101, 'year'))
    data.data_prepare()
    data.get_embedding()
    list_data.append(data)
    
    reload(model)
    tf.reset_default_graph()
    mod = model.Model(1, '{}_{}_{}'.format(2004010120140101+i, 2014010120150101, 'year'))
    mod.data_initial(data)
    mod.factor_network() 
    list_mod.append(mod)
    
    for j in range(3):
        model_num = j
        saver = tf.train.Saver(max_to_keep=50)
        data_dir = '/data/zhige_data/huaxia_embedding/'
        with tf.Session() as sess:
            saver.restore(sess, data_dir+'{}model_{}/logmodel.ckpt'.format(model_num, mod.param))
            embedding = mod.data.embedding[:len(mod.data.list_stocks), :]
            hold_place = np.zeros(len(mod.data.list_stocks))
            feed_dict = {mod.embedding: embedding, mod.factor: hold_place, mod.factor_index: [0], mod.ic: hold_place}
            u_bias = sess.run(mod.u_bias, feed_dict=feed_dict)
        hidden = np.matmul(embedding, u_bias.T)
        confidence = np.exp(hidden) / np.sum(np.exp(hidden), axis=0)
        list_confidence.append(confidence)
# Out:
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/0model_2004010120140101_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/1model_2004010120140101_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/2model_2004010120140101_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/0model_2004010120140102_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/1model_2004010120140102_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/2model_2004010120140102_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/0model_2004010120140103_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/1model_2004010120140103_2014010120150101_year/logmodel.ckpt
# INFO:tensorflow:Restoring parameters from /data/zhige_data/huaxia_embedding/2model_2004010120140103_2014010120150101_year/logmodel.ckpt

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
for num, confidence in enumerate([list_confidence[0]]):
    print('count: {}'.format(num))
    for fac_idx in range(44):
        print(fac_idx)
        arg_sort = confidence[:, fac_idx].argsort()
        print('  the max:')
        for arg in arg_sort[-10:]:
            stock = list_data[num].list_stocks[arg]
            try:
                name = data.dict_code2name[stock].split(';')[-2]
            except:
                name = 'not know'
            print('    ', stock, name, confidence[arg, fac_idx])
        
        print('  the min:')
        for arg in arg_sort[:10]:
            stock = list_data[num].list_stocks[arg]
            try:
                name = data.dict_code2name[stock].split(';')[-2]
            except:
                name = 'not know'
            print('    ', stock, name, confidence[arg, fac_idx])
# Out:
# count: 0
# 0
#   the max:
#      300336 传媒-新 文 化 0.00434917012095
#      300172 电力及公用事业-中电环保 0.00440107980738
#      300161 机械-华中数控 0.00441044530794
#      300075 计算机-数字政通 0.00446936281611
#      300104 传媒-乐 视 网 0.00519447936345
#      300148 传媒-天舟文化 0.00540109250551
#      300352 计算机-北 信 源 0.00556692848485
#      300065 国防军工-海 兰 信 0.00573682913664
#      300287 计算机-飞 利 信 0.00650784673454
#      300253 计算机-卫宁健康 0.0079873815933
#      000688 有色金属-建新矿业 8.41671093844e-06
#      002644 医药-佛慈制药 8.86150795939e-06
#      300320 基础化工-海达股份 8.96668131546e-06
#      300353 通信-东土科技 1.03724078115e-05
#      600753 建材-东方银星 1.03985796685e-05
#      002552 机械-宝鼎科技 1.07447862584e-05
# 31
#   the max:
#      300246 医药-宝 莱 特 0.00325693635937
#      300336 传媒-新 文 化 0.00330850103051
#      603008 轻工制造-喜 临 门 0.00332401190154
#      300028 电子元器件-金亚科技 0.00335554658649
#      300174 基础化工-元力股份 0.00371219167976
#      300075 计算机-数字政通 0.00383264715636
#      300352 计算机-北 信 源 0.00418316134467
#      300065 国防军工-海 兰 信 0.00435727670254
#      300287 计算机-飞 利 信 0.00566283150272
#      300253 计算机-卫宁健康 0.00591800313793
#   the min:
#      000035 电力及公用事业-中国天楹 3.00130767873e-07
#      000820 轻工制造-神雾节能 4.95840145415e-07
#      000622 汽车-恒立实业 7.11140710105e-07
#      000672 建材-上峰水泥 7.29387195194e-07
#      000018 房地产-神州长城 8.34637756517e-07
#      000757 汽车-浩物股份 8.58747247595e-07
#      000038 房地产-深 大 通 1.04424479715e-06
#      000509 建材-华塑控股 1.09156795019e-06
#      000010 建筑-美丽生态 1.28741022418e-06
#      000058 房地产-深 赛 格 1.67520240385e-06
# 32
#   the max:
#      600766 有色金属-园城黄金 0.0132615501155
#      600603 房地产-广汇物流 0.0136196175603
#      300200 基础化工-高盟新材 0.0156753045094
#      000062 房地产-深圳华强 0.0207753256528
#      600613 医药-神奇制药 0.020910383137
#      300333 计算机-兆日科技 0.0234353491167
#      300269 电子元器件-联建光电 0.0243851853995
#      002592 汽车-八菱科技 0.0261351703628
#      000691 房地产-ST 亚太 0.0274325464531
#      002354 传媒-天神娱乐 0.15700047439
#   the min:
#      600182 汽车-S 佳  通 1.65062153982e-08
#      600094 房地产-大 名 城 2.10821683969e-08
#      000068 电力及公用事业-华控赛格 2.21147788311e-08
#      002647 电子元器件-民盛金科 2.56849902102e-08
#      600688 石油石化-S 上石化 3.28785548343e-08
#      000429 交通运输-Ｇ粤高速 3.37811811251e-08
#      300265 电力设备-通光线缆 3.8775083058e-08
#      000949 基础化工-Ｇ 新 纤 4.06459790493e-08
#      000668 房地产-荣丰控股 4.62736787592e-08
#      600556 房地产-ST 慧 球 5.62248394668e-08
# 33
#   the max:
#      300324 计算机-旋极信息 0.00289998073685
#      002486 纺织服装-嘉 麟 杰 0.00296490643008
#      300149 农林牧渔-量子高科 0.0029653767729
#      300336 传媒-新 文 化 0.00307006763919
#      300065 国防军工-海 兰 信 0.00333989418516
#      300253 计算机-卫宁健康 0.00374084290192
#      300246 医药-宝 莱 特 0.00379614251065
#      300148 传媒-天舟文化 0.00427118411803
#      300287 计算机-飞 利 信 0.00493990114297
#      300028 电子元器件-金亚科技 0.00540721183187
#   the min:
#      000035 电力及公用事业-中国天楹 4.18075915947e-07
#      000820 轻工制造-神雾节能 8.57821471833e-07
#      000622 汽车-恒立实业 1.05440257416e-06
#      000509 建材-华塑控股 1.19377197622e-06
#      000672 建材-上峰水泥 1.2779265878e-06
#      000038 房地产-深 大 通 6.08504045573e-07
#      000058 房地产-深 赛 格 6.09924352024e-07
#      000010 建筑-美丽生态 6.95958750041e-07
#      000757 汽车-浩物股份 8.18720757914e-07
# 37
#   the max:
#      300113 通信-顺网科技 0.00134933831321
#      300177 计算机-中 海 达 0.00135317102395
#      300287 计算机-飞 利 信 0.00135413571364
#      300205 通信-天喻信息 0.00136153441825
#      300322 通信-硕 贝 德 0.00141202391669
#      002610 电力设备-爱康科技 0.00142420660677
#      300353 通信-东土科技 0.00144849740524
#      300207 电子元器件-欣 旺 达 0.00146606390357
#      300253 计算机-卫宁健康 0.00161308511491
#      300352 计算机-北 信 源 0.00194074516509
#   the min:
#      000035 电力及公用事业-中国天楹 2.39437212019e-05
#      000058 房地产-深 赛 格 2.63915780592e-05
#      600807 房地产-天业股份 2.84246131641e-05
#      603399 有色金属-新 华 龙 2.84712589096e-05
#      000622 汽车-恒立实业 3.08688636442e-05
#      000820 轻工制造-神雾节能 3.45693579649e-05
#      300321 基础化工-同大股份 3.56350771654e-05
#      000018 房地产-神州长城 3.61160991649e-05
#      600768 有色金属-S 甬富邦 3.71052739253e-05
#      000672 建材-上峰水泥 3.92525696395e-05
# 38
#   the max:
#      000151 商贸零售-Ｇ 中 成 0.0101112940434
#      300208 电力设备-恒顺众昇 0.010117810599
#      002686 机械-亿 利 达 0.0104597689314
#      600215 房地产-长春经开 0.0131460495692
#      002531 电力设备-天顺风能 0.0157520601245
#      002487 电力设备-大金重工 0.0210531514846
#      002514 机械-宝馨科技 0.0216690500288
#      300327 电子元器件-中颖电子 0.0221970037977
#      000615 基础化工-京汉股份 0.0256027091373
#      300269 电子元器件-联建光电 0.0958832570898
#   the min:
#      000429 交通运输-Ｇ粤高速 3.41598878423e-07
#      000628 房地产-高新发展 3.55905524017e-07
#      600007 房地产-Ｇ 国 贸 4.20393217019e-07
#      600531 有色金属-Ｇ 豫 光 4.65123544481e-07
#      300268 农林牧渔-万福生科 4.78287111367e-07
#      000750 非银行金融-国海证券 5.03623208584e-07
#      600556 房地产-ST 慧 球 5.31522014653e-07
#      300276 机械-三丰智能 5.71513645958e-07
#      300213 通信-佳讯飞鸿 6.40452111249e-07
#      002145 基础化工-*ST 钛白 6.58779125e-07
# 39
#   the max:
#      300277 计算机-海 联 讯 0.00512640166637
#      300148 传媒-天舟文化 0.00524159443615
#      300246 医药-宝 莱 特 0.00545449298353
#      300075 计算机-数字政通 0.00553409222579
#      300336 传媒-新 文 化 0.00559657613888
#      300085 计算机-银 之 杰 0.0056580501901
#      300104 传媒-乐 视 网 0.00805997298452
#      300028 电子元器件-金亚科技 0.00823055830573
#      300287 计算机-飞 利 信 0.00944291621282
#      300253 计算机-卫宁健康 0.0118896859224
#   the min:
#      000035 电力及公用事业-中国天楹 9.6500146009e-08
#      000672 建材-上峰水泥 2.39462677686e-07
#      000820 轻工制造-神雾节能 2.49159066307e-07
#      002596 建材-海南瑞泽 2.68026025761e-07
#      000058 房地产-深 赛 格 3.29246663101e-07
#      000018 房地产-神州长城 3.45165961444e-07
#      000757 汽车-浩物股份 7.61498333884e-07
#      000010 建筑-美丽生态 8.0662567351e-07
#      000038 房地产-深 大 通 8.84723235549e-07
#      600624 综合-Ｇ 复 华 1.05130286931e-06
#      000058 房地产-深 赛 格 1.14699350003e-06
# 43
#   the max:
#      600170 建筑-Ｇ 建 工 0.00248480854136
#      601727 电力设备-上海电气 0.00252261558251
#      000729 食品饮料-Ｇ 燕 啤 0.00257155587873
#      000878 有色金属-Ｇ 云 铜 0.00268960143915
#      600015 银行-Ｇ 华 夏 0.00276812214732
#      600861 商贸零售-Ｇ京城乡 0.00288720059732
#      000046 房地产-泛海控股 0.00314048759964
#      600489 有色金属-Ｇ中黄金 0.00316935902522
#      600780 电力及公用事业-Ｇ 通 宝 0.0036725912002
#      603993 有色金属-洛阳钼业 0.00470064938922
#   the min:
#      601599 传媒-鹿港文化 2.67147054452e-08
#      002608 机械-江苏国信 3.75800762823e-08
#      601218 电力设备-吉鑫科技 5.09548447674e-08
#      000030 综合-富奥股份 6.40120865893e-08
#      002578 有色金属-闽发铝业 6.77732255373e-08
#      002533 电力设备-金杯电工 9.88941186451e-08
#      002464 基础化工-金利科技 1.01201305839e-07
#      002451 电力设备-摩恩电气 1.05290685858e-07
#      002681 电子元器件-奋达科技 1.11388250047e-07
#      002654 电子元器件-万润科技 1.15920803179e-07

# %%
list_confidence[0].shape
# Out:
# (2422, 44)

# %% [markdown]
# # Prediction

# %%
data_list = []
mod_list = []
for i in range(3):
    data = Datum('{}_{}_{}'.format(2004010120140101+i, 2014010120150101, 'year'))
    data.data_prepare()
    data.get_embedding()
    data.supervised_data_prepare()
    data.ic_prepare()
    data_list.append(data)


    mod = model.Model(1, '{}_{}_{}'.format(2004010120140101+i, 2014010120150101, 'year'))
    mod.data_initial(data)
    mod.data_split()
    mod_list.append(mod)

# %%
zhongzheng500 = list(pd.read_csv('/data/zhige_data/zhongzheng500.csv', header=None, dtype=str)[0])
use_index = [i for i in range(len(data.list_stocks)) if data.list_stocks[i] in zhongzheng500]
next_return = data.price_data - data.price_data.mean(axis=0)
next_return = next_return[np.array(use_index)]
raw_feature = data.feature_data[np.array(use_index)]
new_feature = np.zeros(data.feature_data.shape)

# %%
tf.reset_default_graph()
emb_num = 0
model_num = 0
mod = mod_list[emb_num]
mod.factor_network() 
saver = tf.train.Saver(max_to_keep=50)
with tf.Session() as sess:
    saver.restore(sess, data_dir+'{}model_{}/logmodel_{}.ckpt'.format(model_num, mod.param, model_num_list[3*emb_num+model_num]))
    embedding = mod.data.embedding[:len(mod.data.list_stocks), :]
    for day in range(mod.train_vali,mod.vali_test):
        for fac_idx in range(44):
            feature = mod.data.feature_data[:, day, fac_idx]
            if feature.std() != 0:
                feature = (feature-feature.min()) / (feature.max() - feature.min())
            else:
                continue
            label = mod.data.ar_ic[:, day, 2]
            feed_dict = {mod.embedding: embedding, mod.factor: feature, mod.factor_index: [fac_idx], mod.ic: label}
            new_f, loss_val = sess.run([mod.new_f, mod.cost], feed_dict=feed_dict)
            new_feature[:, day, fac_idx] = new_f
